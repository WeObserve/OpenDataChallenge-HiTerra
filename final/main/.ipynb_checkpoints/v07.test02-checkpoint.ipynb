# %% [markdown]
# ## Test with df_test data and visualise
#
# #### Inputs:
# - df_train02.csv
# - df_test02.csv
# - df_chunk_train02.csv
# - df_chunk_test02.csv
# - normalizer.pkl
# - batcher_train_lite_model03.pkl: batcher object that training was done
# - model03_epoch199.pkl: Latest model
#
# #### Output:
# - tester_model03_epoch199.pkl: tester object that keeps estimations and errors

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import pickle
import sys
from importlib import reload
import logging
import torch

# %matplotlib inline

# %%
sys.path.append('..')

# %% [markdown]
# #### Load data

# %%
df_train = pd.read_csv('../data/df_train02.csv',  parse_dates=['Datetime'])
df_chunk_train = pd.read_csv('../data/df_chunk_train02.csv')

# %%
df_test = pd.read_csv('../data/df_test02.csv',  parse_dates=['Datetime'])
df_chunk_test = pd.read_csv('../data/df_chunk_test02.csv')

# %% [markdown]
# #### Load normalizer

# %%
import normalizing as nr

# %%
# normalizer = nr.Normalizer(meanstd=['temperature', 'apparent_temperature', 'dew_point',
#                                    'wind_speed', 'wind_gust'],
#                       minmax=['visibility', 'precip_intensity', 'Moisture',
#                               'Day', 'Hour', 'Month', 'Weekday'])

# df_train = normalizer.normalize(df_train, init=True)

# %%
with open('../data/normalizer2.pkl' ,'rb') as f:
    normalizer = pickle.load(f)

# %% [markdown]
# #### Load light batcher object

# %%
import batching as bt

# %%
bt = reload(bt)

# %%
with open('../data/batcher_train_lite_eawc_model03.pkl', 'rb') as f:
    batcher_train = pickle.load(f)

# %% [markdown]
# #### Load the trained LSTM model

# %%
import lstm

# %%
lstm = reload(lstm)

# %%
model = torch.load('../data/model03_epoch199.pkl', map_location=torch.device('cpu'))

# %%
model.move_cpu()

# %% [markdown]
# #### Set test parameters

# %%
test_period = 24
init_len = 168
out_filter_len = 18

# %% [markdown]
# #### Create a tester object with df_test

# %%
import testing as ts

# %%
ts = reload(ts)

# %%
tester = ts.TesterMain(df_test,
                       df_chunk_test,
                       batcher_train.inp_time_len,
                       init_len,
                       test_period,
                       out_filter_len,
                       batcher_train.col_feats_prev,
                       batcher_train.col_feats_current,
                       normalizer
                      )

# %%
tester.init()

# %%
tester.run(model)
# Out:
# MAPE IS: 0.06927112961874897

# %%
tester.visualise_rand()

# %%
with open('../data/tester_model03_epoch199.pkl', 'wb') as f:
    pickle.dump(tester, f)

# %%
plt.hist(tester.mapes, bins=100, range=[0,0.25]);

# %%
inds_sorted = np.argsort(tester.mapes)

# %%
ii = -1

# %%
ii += 1
# ii -= 2
tester.testers[inds_sorted[ii]].visualise()
